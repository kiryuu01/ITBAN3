# %%
import tensorflow as tf

# %%
plt.plot(x, y, '.', label="Data")
plt.plot(x, f(x), label="Ground truth")
plt.plot(x, model(x), label="Predictions")
plt.legend()
plt.show()

print("Current loss: %1.6f" % loss(y, model(x)).numpy())
# Out:
# Current loss: 10.139905

# %% [markdown]
# Before Training: I noticed in the graph that the data and ground truth are together but not aligned with the possible predictions, and its current loss is high at 10.13.

# %%
current_loss = loss(y, model(x))

print(f"Starting:")
print("    ", report(model, current_loss))

training_loop(model, x, y)
# Out:
# Starting:
#      W = 3.08, b = 1.75, loss=0.94442
# Epoch  0:
#      W = 3.06, b = 1.79, loss=0.92376
# Epoch  1:
#      W = 3.04, b = 1.82, loss=0.91104
# Epoch  2:
#      W = 3.03, b = 1.85, loss=0.90316
# Epoch  3:
#      W = 3.02, b = 1.87, loss=0.89827
# Epoch  4:
#      W = 3.01, b = 1.89, loss=0.89521
# Epoch  5:
#      W = 3.01, b = 1.90, loss=0.89330
# Epoch  6:
#      W = 3.00, b = 1.91, loss=0.89209
# Epoch  7:
#      W = 3.00, b = 1.92, loss=0.89134
# Epoch  8:
#      W = 3.00, b = 1.93, loss=0.89086
# Epoch  9:
#      W = 3.00, b = 1.94, loss=0.89055

# %% [markdown]
# As the loss decreases across epochs, the model shows evidence of integration, suggesting a gain in performance. The model reaches ideal weight and bias values at the end of training, which lowers the loss value. All things considered, the model shows good based on data learning and setting parameters that better represent underlying trends and increase prediction accuracy.

# %%
plt.plot(x, y, '.', label="Data")
plt.plot(x, f(x), label="Ground truth")
plt.plot(x, model(x), label="Predictions")
plt.legend()
plt.show()

print("Current loss: %1.6f" % loss(model(x), y).numpy())
# Out:
# Current loss: 0.944422

# %% [markdown]
# After Training:
# Now, after the training, while the current loss decreased, the data and ground truth aligned perfectly with the predictions line, and the current loss is now 0.94.
